# %% [markdown]
# #📌 Extracción

# %% [markdown]
# importar los datos de la API de Telecom X. Estos datos están disponibles en formato JSON junto a las bibliotecas a utilizar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/main/TelecomX_Data.json'
df = pd.read_json(url)
df.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.tail()
# Out:
#       customerID Churn                                           customer  \
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# 7262     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7263    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 7264     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7265     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7266  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                                internet  \
# 7262  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
df.sample(7)
# Out:
#       customerID Churn                                           customer  \
# 1594  2266-FUBDZ    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2553  3566-HJGPK    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1733  2465-BLLEU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 1348  1945-XISKS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 4425  6061-GWWAV    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 127   0215-BQKGS    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4415  6047-SUHPR    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                phone  \
# 1594  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 2553  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1733  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1348  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4425  {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %% [markdown]
# #🔧 Transformación

# %%
df_normalizado = pd.json_normalize(
    data=df.to_dict(orient='records'),
    record_path=None,
    meta=['customerID', 'Churn'],
    errors='ignore'
)

nuevos_nombres = {
    'customer.gender': 'genero del cliente',
    'customer.SeniorCitizen': 'cliente senior',
    'customer.Partner': 'cliente con pareja',
    'customer.Dependents': 'cliente con dependientes',
    'phone.PhoneService': 'cliente con servicio telefonico',
    'phone.MultipleLines': 'cliente con multiples lineas',
    'internet.InternetService': 'servicio de internet',
    'internet.OnlineSecurity': 'seguridad en linea',
    'internet.OnlineBackup': 'backup en linea',
    'internet.DeviceProtection': 'proteccion de dispositivo',
    'internet.TechSupport': 'soporte tecnico',
    'internet.StreamingTV': 'streaming tv',
    'internet.StreamingMovies': 'streaming movies',
    'account.Contract': 'Tipo de contrato',
    'account.PaperlessBilling': 'Facturacion en linea',
    'account.PaymentMethod': 'Metodo de pago',
    'account.Charges.Monthly': 'costo mensual',
    'account.Charges.Total': 'costo total',
    'customer.tenure':'Meses de contrato del cliente'
}

df_normalizado = df_normalizado.rename(columns=nuevos_nombres)
df_normalizado.head()
# Out:
#    customerID Churn genero del cliente  cliente senior cliente con pareja  \
# 0  0002-ORFBO    No             Female               0                Yes
# 1  0003-MKNFE    No               Male               0                 No
# 2  0004-TLHLJ   Yes               Male               0                 No
# 3  0011-IGKFF   Yes               Male               1                Yes
# 4  0013-EXCHZ   Yes             Female               1                Yes
#
#   cliente con dependientes  Meses de contrato del cliente  \
# 0                      Yes                              9
# 1                       No                              9
# 2                       No                              4
# 3                       No                             13
# 4                       No                              3
#
#   cliente con servicio telefonico cliente con multiples lineas  \
# 0                             Yes                           No
# ...

# %%
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customerID                       7267 non-null   object
#  1   Churn                            7267 non-null   object
#  2   genero del cliente               7267 non-null   object
#  3   cliente senior                   7267 non-null   int64
#  4   cliente con pareja               7267 non-null   object
#  5   cliente con dependientes         7267 non-null   object
#  6   Meses de contrato del cliente    7267 non-null   int64
#  7   cliente con servicio telefonico  7267 non-null   object
#  8   cliente con multiples lineas     7267 non-null   object
#  9   servicio de internet             7267 non-null   object
#  10  seguridad en linea               7267 non-null   object
#  11  backup en linea                  7267 non-null   object
# ...

# %%
df_normalizado['costo total']=df_normalizado['costo total'].replace(' ',0.0)
df_normalizado['costo total'] = df_normalizado['costo total'].astype(np.float64)
df_normalizado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   customerID                       7267 non-null   object
#  1   Churn                            7267 non-null   object
#  2   genero del cliente               7267 non-null   object
#  3   cliente senior                   7267 non-null   int64
#  4   cliente con pareja               7267 non-null   object
#  5   cliente con dependientes         7267 non-null   object
#  6   Meses de contrato del cliente    7267 non-null   int64
#  7   cliente con servicio telefonico  7267 non-null   object
#  8   cliente con multiples lineas     7267 non-null   object
#  9   servicio de internet             7267 non-null   object
#  10  seguridad en linea               7267 non-null   object
#  11  backup en linea                  7267 non-null   object
# ...

# %%
df_normalizado.isna().isnull().sum()
# Out:
# customerID                         0
# Churn                              0
# genero del cliente                 0
# cliente senior                     0
# cliente con pareja                 0
# cliente con dependientes           0
# Meses de contrato del cliente      0
# cliente con servicio telefonico    0
# cliente con multiples lineas       0
# servicio de internet               0
# seguridad en linea                 0
# backup en linea                    0
# proteccion de dispositivo          0
# soporte tecnico                    0
# streaming tv                       0
# streaming movies                   0
# Tipo de contrato                   0
# Facturacion en linea               0
# Metodo de pago                     0
# costo mensual                      0
# costo total                        0
# dtype: int64

# %%
df_normalizado['Churn'] = df_normalizado['Churn'].replace('','unknown')
df_normalizado['Churn'].unique()
# Out:
# array(['No', 'Yes', 'unknown'], dtype=object)

# %%
for i in df_normalizado.select_dtypes(include='object').columns:
  df_normalizado[i]=df_normalizado[i].str.lower().str.strip()

# %%
df_normalizado['costos diarios']=df_normalizado['costo mensual']/30
df_normalizado.head()
# Out:
#    customerID Churn genero del cliente  cliente senior cliente con pareja  \
# 0  0002-orfbo    no             female               0                yes
# 1  0003-mknfe    no               male               0                 no
# 2  0004-tlhlj   yes               male               0                 no
# 3  0011-igkff   yes               male               1                yes
# 4  0013-exchz   yes             female               1                yes
#
#   cliente con dependientes  Meses de contrato del cliente  \
# 0                      yes                              9
# 1                       no                              9
# 2                       no                              4
# 3                       no                             13
# 4                       no                              3
#
#   cliente con servicio telefonico cliente con multiples lineas  \
# 0                             yes                           no
# ...

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# ####calculo de la media, mediana, moda, desviacion estandar y medidas de distribucion y comportamiento

# %%
df_normalizado_medidas = df_normalizado.describe().round(2)
df_normalizado_medidas
# Out:
#        cliente senior  Meses de contrato del cliente  costo mensual  \
# count         7267.00                        7267.00        7267.00
# mean             0.16                          32.35          64.72
# std              0.37                          24.57          30.13
# min              0.00                           0.00          18.25
# 25%              0.00                           9.00          35.42
# 50%              0.00                          29.00          70.30
# 75%              0.00                          55.00          89.88
# max              1.00                          72.00         118.75
#
#        costo total  costos diarios
# count      7267.00         7267.00
# mean       2277.18            2.16
# std        2268.65            1.00
# min           0.00            0.61
# 25%         396.20            1.18
# 50%        1389.20            2.34
# 75%        3778.52            3.00
# max        8684.80            3.96

# %% [markdown]
# ####gráficos para visualizar la proporción de clientes que permanecieron y los que se dieron de baja usando la variable 'churn'.

# %%
# Gráfico de barras para la proporción de clientes que permanecieron y los que se dieron de baja
churn_counts = df_normalizado['Churn'].value_counts().reset_index()
churn_counts.columns = ['Churn', 'Count']

plt.figure(figsize=(6, 4))
sns.barplot(x='Churn', y='Count', data=churn_counts, palette='Set2')
plt.title('Proporción de clientes por Churn')
plt.xlabel('Churn')
plt.ylabel('Número de clientes')
plt.show()
# Out:
# /tmp/ipython-input-3516401.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Churn', y='Count', data=churn_counts, palette='Set2')

# %% [markdown]
# ####distribucion de evasión según variables categóricas, como género, tipo de contrato, método de pago, entre otras.*texto en cursiva*

# %%
# Distribución de evasión según variables categóricas
categorical_cols = ['genero del cliente', 'cliente senior', 'cliente con pareja', 'cliente con dependientes',
                    'cliente con servicio telefonico', 'cliente con multiples lineas', 'servicio de internet',
                    'seguridad en linea', 'backup en linea', 'proteccion de dispositivo', 'soporte tecnico',
                    'streaming tv', 'streaming movies', 'Tipo de contrato', 'Facturacion en linea', 'Metodo de pago']

plt.figure(figsize=(10, 40))
plt.subplots_adjust(hspace=0.4, wspace=0.3)
for i, col in enumerate(categorical_cols):
    plt.subplot(8, 2, i + 1)
    sns.countplot(x=col, hue='Churn', data=df_normalizado)
    plt.title(f'Distribución de Churn por {col}')
    plt.xlabel(col)
    plt.ylabel('Número de clientes')
    plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ####exploracion de las variables numéricas, como "total gastado" o "tiempo de contrato", y como se distribuyen entre los clientes que cancelaron y los que no cancelaron por medio de graficos.

# %%
numerical_cols = ['Meses de contrato del cliente', 'costo mensual', 'costo total', 'costos diarios']

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.histplot(data=df_normalizado, x=col, hue='Churn', kde=True)
    plt.title(f'Distribución de {col} por Churn')
    plt.xlabel(col)
    plt.ylabel('Frecuencia')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 20))
for i, col in enumerate(numerical_cols):
    plt.subplot(2, 2, i + 1)
    sns.boxplot(data=df_normalizado, x='Churn', y=col, hue='Churn', palette='Set2', legend=False) # Added hue='Churn' and legend=False
    plt.title(f'Distribución de {col} por Churn (Box Plot)')
    plt.xlabel('Churn')
    plt.ylabel(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# ##  Introducción
# El presente análisis tuvo como objetivo principal estudiar el problema de **evasión de clientes (Churn)** en la empresa **Telecom X**. La evasión de clientes representa un desafío estratégico para las compañías de telecomunicaciones, ya que impacta directamente en sus ingresos y sostenibilidad.
# Mediante el uso de técnicas de **análisis de datos** se buscó identificar patrones, factores de riesgo y variables relevantes que influyen en la decisión de los clientes de cancelar el servicio.
#
# ---
#
# ### 🔹 Limpieza y Tratamiento de Datos
# 1. **Importación de Datos**: Se cargó la base de datos desde un archivo JSON disponible en la API pública de Telecom X.
# 2. **Normalización**: Se utilizó `pd.json_normalize` para aplanar la estructura del dataset y facilitar su análisis.
# 3. **Renombrado de Columnas**: Las variables fueron renombradas a un formato más claro y comprensible (ejemplo: `customer.gender` → `género del cliente`).
# 4. **Verificación de Nulos y Tipos de Datos**: Se revisó la consistencia de la información con `df.info()` y se trataron variables con valores faltantes o inconsistentes.
# 5. **Transformaciones**: Se prepararon variables categóricas y numéricas para facilitar la exploración y visualización.
#
# ---
#
# ## 🔹 Análisis Exploratorio de Datos (EDA)
# Durante la fase de exploración se utilizaron gráficos y estadísticas descriptivas para comprender el comportamiento de los clientes y su relación con la evasión:
#
# - **Distribución del Churn**: Se analizó la proporción de clientes que abandonaron vs. los que permanecieron.
# - **Características Demográficas**: Variables como género, edad (cliente senior) y situación familiar mostraron distintos niveles de evasión.
# - **Servicios Contratados**: La falta de servicios de seguridad en línea, soporte técnico y protección de dispositivos estuvo asociada con mayores niveles de churn.
# - **Tipo de Contrato**: Los clientes con contratos **mensuales** presentaron una tasa de evasión significativamente más alta frente a los contratos de uno o dos años.
# - **Costos y Facturación**: Clientes con costos mensuales más elevados tendieron a abandonar en mayor proporción, especialmente si usaban facturación electrónica.
#
# 📊Las visualizaciones realizadas (barras, histogramas, heatmaps y gráficos interactivos) reforzaron estos hallazgos mostrando correlaciones entre el churn y las variables mencionadas.
#
# ---
#
# ## 🔹 Conclusiones e Insights
# - La **evasión de clientes** está fuertemente asociada a contratos de corto plazo y altos costos mensuales.
# - Los servicios adicionales como **seguridad en línea** y **soporte técnico** juegan un rol clave en la retención.
# - La facturación en línea y ciertos métodos de pago presentan relación con la cancelación del servicio.
# - Los clientes seniors y sin dependientes tienden a mostrar tasas más altas de churn.
#
# En general, los datos muestran que la combinación de factores económicos (precio), contractuales (tipo de contrato) y de servicio (calidad y soporte) son determinantes en la decisión del cliente.
#
# ---
#
# ## 🔹 Recomendaciones
# 1. **Incentivar contratos de mayor duración** (anual o bianual) mediante descuentos o beneficios exclusivos.
# 2. **Optimizar costos mensuales** con planes personalizados que se ajusten al perfil de consumo del cliente.
# 3. **Fortalecer servicios adicionales** como soporte técnico y seguridad en línea para aumentar la percepción de valor.
# 4. **Segmentación proactiva**: Identificar clientes con alto riesgo de evasión (ej. contrato mensual, altos costos, sin servicios adicionales) y ofrecerles retención temprana.
# 5. **Mejorar la experiencia de pago y facturación**, ofreciendo múltiples métodos que se adapten a las necesidades del cliente.
#
# ---
